# %% [markdown]
# # chaos

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
#https://github.com/ganguli-lab/deepchaos
#Chaos

k=5
delta=0.3
lam = 1/250
D=0
I0=0.65
x=0.998
b=500

m =300
b = 10
a = 0.98

# %%
T=[0.9998]#0.9998
u = [0.5]
v=[random.random()]#random.random()

# %%
for k in range(1, m):
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    #
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

# %%
f = plt.figure(figsize=(30,9))
sns.set_style("darkgrid")
plt.plot(u,'.' )
#print(epoch)

# %% [markdown]
# # Annealing

# %%
b = 10
a = 0.98
t=[1]
for k in range(1, 300):
    t.append((1 / (b + 1)) * (b + (math.tanh(a) ** k))* t[k-1] )

# %%
plt.plot(t)
#print(t)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
#https://github.com/ganguli-lab/deepchaos
#Chaos


k=5
delta=0.3
lam = 1/250
D=0
I0=0.65
x=0.998
b=500

m =300
b = 10
a = 0.98

T=[0.01]#2.73
u = [0.5]
v=[0.003]
for k in range(1, m):
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    #
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

# %%
f = plt.figure(figsize=(19,5))
sns.set_style("darkgrid")
plt.plot(u,'.' )
#print(epoch)

# %%
T=[0.01]
u = [0.5]
v=[0.003]
b=300
lam = 1/250
delta=0.3
D=0
I0=0.65
callback_num=1

def chaos_CallBack(epoch):
    T.append((1 / (b + 1))*(b+(math.tanh(a) ** epoch))*T[epoch])
    return T[-2]
    u.append(1/(1+np.exp(-v[epoch]/lam)))
    v.append(delta*math.sin(math.pi*v[epoch])+D-T[epoch]*(u[epoch]-I0))

# %%
k=5
delta=0.3
lam = 1/250
D=0
I0=0.65
x=0.998
b=500

m =300
b = 10
a = 0.98

T=[0.01]#2.73
u = [0.5]
v=[0.003]

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
#https://github.com/ganguli-lab/deepchaos
#Chaos
#我改了 9/20 b原本=5 改成300

k=5
delta=0.3
lam = 1/3000

D=0
I0=0.65
x=0.998
b=500

m =4000
b = 300

T=[1]#2.73
u = [0.5]
v=[0.003]
for k in range(1, m):
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    #
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: overflow encountered in exp

# %%
f = plt.figure(figsize=(19,5))
sns.set_style("darkgrid")
plt.plot(u,'.' )
#print(epoch)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
#https://github.com/ganguli-lab/deepchaos
#Chaos
#我改了 9/20 b原本=5 改成300

delta=0.15
lam = 1/900

D=0
I0=0.5
x=0.98

m =500
b = 100

T=[0.08]#2.73
u = [0.5]
v=[0.003]
for k in range(1, m):
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
    
offset = 150 #調整
u = u[offset:]
b = 50
a = 0.5
t=[0.01]
u[0] = u[0] * t[0]*100

for k in range(1, m+1 - offset):
    t.append((1 / (b + 1)) * (b + (math.tanh(a) ** k))* t[k-1])
    u[k] = ((u[k] + t[k]*30) * t[k] * 100)

u = [1]
for k in range(0, m):
    u.append(u[k] - 0.0308)

f = plt.figure(figsize=(13,5))
sns.set_style("darkgrid")
plt.plot(u,'.' )
#print(epoch)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
#https://github.com/ganguli-lab/deepchaos
#Chaos
#我改了 9/20 b原本=5 改成300

delta=0.15
lam = 1/900

D=0
I0=0.5
x=0.98

m =500
b = 100

T=[0.08]#2.73
u = [0.5]
v=[0.003]
for k in range(1, m):
    
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
    
offset = 150 #調整
u = u[offset:]
b = 50
a = 0.5
t=[0.01]
u[0] = u[0] * t[0]*100

for k in range(1, m+1 - offset):#+1
    
    t.append((1 / (b + 1)) * (b + (math.tanh(a) ** k))* t[k-1])
    u[k] = ((u[k] + t[k]*30) * t[k] * 100)



f = plt.figure(figsize=(10,5))
sns.set_style("darkgrid")
plt.plot(u,'.' )
#print(epoch)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
#https://github.com/ganguli-lab/deepchaos
#Chaos
#我改了 9/20 b原本=5 改成300

delta=0.3
lam = 1/3000

D=0
I0=0.65

m =300
b = 30
x=0.5

T=[0.01]#2.73
u = [0.5]
v=[0.003]
for x in np.arange(0.2, 1, 0.005):
    T=[0.01]#2.73
    u = [0.5]
    v=[0.003]
    for k in range(1, m):
        T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

    for k in range(0, m):
        u.append(1/(1+np.exp(-v[k]/lam)))
        v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    f.suptitle('x=%s' % (x), fontsize=16)
    plt.plot(u,'.' )
#print(epoch)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tqdm import tqdm
# %matplotlib inline
def AAA():
    m=300
    for delta in tqdm(np.arange(0.31, 0.31, 0.1)):
        for lam in range(500, 3000, 100):
            lamb = 1/lam
            for I0 in np.arange(0.5, 0.8, 0.1):
                for x in np.arange(0.98, 1, 0.005):
                    for b in [50]:
                        for t in[0.08]:
                            for v in [0.003]:
                                D=0
                               # print('delta=%s, lamb=1/%s, D=%s, I0=%s, x=%s, b=%s, t=%s, v=%s' % (delta, lam, D, I0, x, b, t, v))
                                T=[t]#2.73
                                u = [0.5]
                                v=[v]
                                for k in range(1, m):
                                    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

                                for k in range(0, m):
                                    u.append(1/(1+np.exp(-v[k]/lamb)))
                                    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

                                f = plt.figure(figsize=(19,5))
                                f.suptitle('delta=%s, lamb=%s, D=%s, I0=%s, x=%s, b=%s' % (delta, lam, D, I0, x, b), fontsize=16)
                                plt.plot(u,'.' )
AAA()
plt.show()
# Out:
# 0it [00:00, ?it/s]

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
def AAA():
    m=300
    for delta in np.arange(0.1, 0.31, 0.01):
        for lam in range(500, 3000, 100):
            lamb = 1/lam
            for I0 in np.arange(0.5, 0.8, 0.1):
                for x in np.arange(0.98, 1, 0.005):
                    for b in [50]:
                        for t in[0.08]:
                            for v in [0.003]:
                                D=0
                               # print('delta=%s, lamb=1/%s, D=%s, I0=%s, x=%s, b=%s, t=%s, v=%s' % (delta, lam, D, I0, x, b, t, v))
                                T=[t]#2.73
                                u = [0.5]
                                v=[v]
                                for k in range(1, m):
                                    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

                                for k in range(0, m):
                                    u.append(1/(1+np.exp(-v[k]/lamb)))
                                    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

                                f = plt.figure(figsize=(19,5))
                                f.suptitle('delta=%s, lamb=%s, D=%s, I0=%s, x=%s, b=%s' % (delta, lam, D, I0, x, b), fontsize=16)
                                plt.plot(u,'.' )
# AAA()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
#https://github.com/ganguli-lab/deepchaos
#Chaos
#我改了 9/20 b原本=5 改成300

k=5
delta=0.3#0.17999999999999997
lam = 1/3000

D=0
I0=0.5
x=1.0

m =300
b = 20


T=[0.01]#0.08
u = [0.5]#0.0
v=[0.003]#0.003


for k in range(1, m):
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
t=[0.01]
for b  in range (1,60,2):#30
    for a in np.arange (0.01,3.0,0.1):
         for k in range(0, m+1):
                
                u[k] = u[k] * t[k] *100
                t.append((1 / (b + 1)) * (b + (math.tanh(a) ** k))* t[k-1])
        
           
       
    
    


f = plt.figure(figsize=(13,5))
sns.set_style("darkgrid")
plt.plot(u,'.' )
#print(epoch)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
#https://github.com/ganguli-lab/deepchaos
#Chaos
#我改了 9/20 b原本=5 改成300

delta=0.15
lam = 1/900

D=0
I0=0.5
x=0.98

m =500
b = 100

T=[0.08]#2.73
u = [0.5]
v=[0.003]
for k in range(1, m):
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
    
offset = 50 #調整
u = u[offset:]
b = 50
a = 0.5
t=[0.01]
u[0] = u[0] * t[0]*100

for k in range(1, m+1 - offset):
     t.append((1 / (b + 1)) * (b + (math.tanh(a) ** k))* t[k-1])
     u[k] = u[k] + t[k]*100

f = plt.figure(figsize=(13,5))
#sns.set_style("darkgrid")
plt.plot(u[150:],'.' )
#print(epoch)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
#https://github.com/ganguli-lab/deepchaos
#Chaos
#我改了 9/20 b原本=5 改成300

k=5
delta=0.14999999999999997#0.17999999999999997
lam = 1/700

D=0
I0=0.5
x=0.98

m =300
b = 50


T=[0.08]#0.08
u = [0.0]#0.0
v=[0.003]#0.003

for k in range(1, m):
    T.append((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

for k in range(0, m):
    #
    u.append(1/(1+np.exp(-v[k]/lam)))
    v.append(delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

f = plt.figure(figsize=(13,5))
#sns.set_style("darkgrid")
plt.plot(u[70:],'.' )
#print(epoch)

# %% [markdown]
# # Experimental results

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.preprocessing.image import ImageDataGenerator, load_img
from PIL import Image
import shutil
import pathlib
import cv2
import os
import csv
import keras
import random
import matplotlib.pyplot as plt
import seaborn as sns
from contextlib import redirect_stdout
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from keras.preprocessing import image
from keras import models
from keras import layers
from keras import optimizers
from keras import applications
from keras.optimizers import Adam
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D,Conv2D,MaxPooling2D,BatchNormalization
from keras import backend as k 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from tqdm import tqdm
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
import math
from keras import backend as K
import time;
from datetime import datetime
from PIL import Image
from keras.utils import multi_gpu_model
a=[]
Run_number=100
min_lr    = 1e-6                                       # 學習率的下限
init_lr   = 0.01                                       # 初始學習率
lr_decay  = -np.log(min_lr/init_lr)/(Run_number-1)  # 衰減係數(自動計算)
def exp_decay_lr(Run_number, init_lr, lr_decay):
    decays2 = np.arange(Run_number+0.0)
    for i in range(len(decays2)): 
        if i==0:
            ss = decays2[i] = math.exp(-lr_decay*i)*init_lr
            
        else:
            ss = decays2[i] = math.exp(-lr_decay*i)*init_lr*(1+decays2[i-1])
            a.append(ss)
                
    return decays2
D2 = exp_decay_lr(Run_number, init_lr, lr_decay)

# Callbacks
patience0 = Run_number
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-d7eb0d5f36ca> in <module>
#      20 from keras import optimizers
#      21 from keras import applications
# ---> 22 from keras.optimizers import Adam
#      23 from keras.models import Sequential, Model
#      24 from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D,Conv2D,MaxPooling2D,BatchNormalization
#
# ImportError: cannot import name 'Adam'

# %%
def lr_decay_callback(init_lr, lr_decay):
    def exp_decay(epoch):
        return init_lr * math.exp(-lr_decay * epoch)
        return Chaotic_Decay[epoch]
        #return D1[epoch]  # Annealed_decay
        #return D2[epoch]  # Exponential_decay
    return LearningRateScheduler(exp_decay)
lr_decays =  lr_decay_callback(init_lr, lr_decay)

# %%
#f = plt.figure(figsize=(13,5))
plt.plot(a)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
# m 步數

def chaos_methods(delta=0.3, lam=2500, D=0, I0=0.95, m=500, b=350, x=1.0, T0=0.015, u0=0.75, v0=0.001,Tv0=0):
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    Tv=[Tv0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    for k in range(1, m):
        
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        Tv[k] = math.sqrt((T[k]-v[k])**2)
    

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    plt.tick_params(axis='both', labelsize=15)
    plt.title("Chaos Learning Rate")
    plt.yticks([0,0.25,0.5,0.75,1])
    plt.savefig("lrCH.png")
        
    return plt
    
w=interactive(chaos_methods,
              
             )
w

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=41
    b=350
    x=0.2
    
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m     
    for k in range(1, m):
        
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)
        if(tv[k]<2e-03):
            tv[k]=2e-03
        else:
            tv[k]=tv[k]
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    return tv[k]
a = lr_schedule(500)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=450
    b=150
    x=0.2
    
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m     
    for k in range(1, m):
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    plt.plot(tv,'.' )
    return tv[k]
a = lr_schedule(450)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=450
    b=125
    x=0.2
    
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m     
    for k in range(1, m):
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    plt.plot(tv,'.' )
    return tv[k]
a = lr_schedule(450)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
Epochs_num = 1
Run_number = 50

# Exponential Decay with learning rate
min_lr    = 1e-5                                      # 學習率的下限
init_lr   = 0.01                                       # 初始學習率
lr_decay  = -np.log(min_lr/init_lr)/(Run_number-1)     #（自動計算)的衰減係數
# Callbacks
patience0 = Run_number  # To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased
def lr_schedule(epoch):

    decays2 = np.arange(epoch+0.0)
    for i in range(len(decays2)): 
        if i==0:
            decays2[i] = math.exp(-lr_decay*i)*init_lr
        else:
            decays2[i] = math.exp(-lr_decay*i)*init_lr*(1+decays2[i-1])
        print(decays2[i])

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(decays2,'.' )
    return decays2[Run_number-1]
a = lr_schedule(50)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=50
    b=20
    x=0.2
    
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m     
    for k in range(1, m):
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(tv,'.' )
    return tv[k]
a = lr_schedule(450)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
# m 步數
def chaos_methods(delta=0.3, lam=3000, D=0, I0=0.65, m=300, b=30, x=0.5, T0=0.01, u0=0.5, v0=0.003,Tv0=0):
    assert lam != 0
    lam = 1 / lam
    Tv=[Tv0] + [0] * m #2.73
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    for k in range(1, m):
        
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        Tv[k] = math.sqrt((T[k]-v[k])**2)
    

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(Tv,'.' )
    plt.plot(T,'.' )
    return plt
    
w=interactive(chaos_methods,
              delta=FloatSlider(min=0, max=1, step=0.05),
              lam=FloatSlider(min=0, max=50000, step=10),
              I0=FloatSlider(min=0, max=2, step=0.05),
              x=FloatSlider(min=0, max=1, step=0.05),
              b=FloatSlider(min=0, max=1000, step=10),
              T0=FloatSlider(min=0, max=1, step=0.05),
              u0=FloatSlider(min=0, max=1, step=0.05),
              v0=FloatSlider(min=0, max=1, step=0.001),
              D=FloatSlider(min=-1, max=1, step=0.05),
              m=IntSlider(min=50, max=5000, step=50),Tv0=FloatSlider(min=0, max=1, step=0.001)
             )
w

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
# m 步數
def chaos_methods(delta=0.3, lam=3000, D=0, I0=0.65, m=300, b=30, x=0.5, T0=0.01, u0=0.5, v0=0.003):
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    for k in range(1, m):
        
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

    ##for k in range(0, m):
        ##u[k+1] = (1/(1+np.exp(-v[k]/lam)))
       ## v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    return plt
    
w=interactive(chaos_methods,
              delta=FloatSlider(min=0, max=1, step=0.05),
              lam=FloatSlider(min=100, max=5000, step=100),
              I0=FloatSlider(min=0, max=2, step=0.05),
              x=FloatSlider(min=0, max=100, step=0.05),
              b=FloatSlider(min=0, max=5000, step=10),
              T0=FloatSlider(min=0, max=1, step=0.05),
              u0=FloatSlider(min=0, max=1, step=0.05),
              v0=FloatSlider(min=0, max=1, step=0.01),
              D=FloatSlider(min=-1, max=1, step=0.05),
              m=IntSlider(min=50, max=5000, step=100),
             )
w

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
# m 步數
def chaos_methods(delta=0.3, lam=3000, D=0, I0=0.65, m=300, b=30, x=0.5, T0=0.01, u0=0.5, v0=0.003):
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    
    for k in range(1, m):
        
        v1=v0
        v0 = (delta*math.sin(math.pi*v0)+D-T0*(u0-I0))
        u0 = (1/(1+np.exp(-v1/lam)))
        T0 = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T0)
        T[k]=v0

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    return plt
    
w=interactive(chaos_methods,
              delta=FloatSlider(min=0, max=1, step=0.05),
              lam=FloatSlider(min=100, max=5000, step=100),
              I0=FloatSlider(min=0, max=2, step=0.05),
              x=FloatSlider(min=0, max=3, step=0.05),
              b=FloatSlider(min=0, max=5000, step=10),
              T0=FloatSlider(min=0, max=1, step=0.05),
              u0=FloatSlider(min=0, max=1, step=0.05),
              v0=FloatSlider(min=0, max=1, step=0.01),
              D=FloatSlider(min=-1, max=1, step=0.05),
              m=IntSlider(min=50, max=5000, step=100),
             )
w

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
# m 步數
def chaos_methods(delta=0.3, lam=3000, D=0, I0=0.65, m=300, b=30, x=0.5, T0=0.01, u0=0.5, v0=0.003):
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    ##for k in range(1, m):
        
        ##T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

    for k in range(0, m):
        T[k+1] = -np.log(u[k]/u[0])/(k+1)
        u[k+1]=u[0] * math.exp(-T[k] * (k+1))
        v[k+1]=(v[k]-(u[k+1]+T[k+1])*(u[k+1]-T[k+1]))**2/v[k]
        


    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    plt.plot(u,'x' )
    plt.plot(v,'o' )
    return plt
    
w=interactive(chaos_methods,
              delta=FloatSlider(min=0, max=1, step=0.05),
              lam=FloatSlider(min=100, max=5000, step=100),
              I0=FloatSlider(min=0, max=2, step=0.05),
              x=FloatSlider(min=0, max=2, step=0.05),
              b=FloatSlider(min=0, max=5000, step=10),
              T0=FloatSlider(min=0, max=1, step=0.05),
              u0=FloatSlider(min=0, max=1, step=0.05),
              v0=FloatSlider(min=0, max=1, step=0.01),
              D=FloatSlider(min=-1, max=1, step=0.05),
              m=IntSlider(min=30, max=5000, step=100),
             )
w

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
# m 步數
def chaos_methods(delta=0.3, lam=3000, D=0, I0=0.65, m=300, b=30, x=0.5, T0=0.01, u0=0.5, v0=0.003):
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    
    for k in range(1, m):
        
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])

    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))

    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(v,'o' )
    plt.plot(u,'.' )
    plt.plot(T,'x' )
    return plt
    
w=interactive(chaos_methods,
              delta=FloatSlider(min=0, max=1, step=0.05),
              lam=FloatSlider(min=100, max=5000, step=100),
              I0=FloatSlider(min=0, max=2, step=0.05),
              x=FloatSlider(min=0, max=3, step=0.05),
              b=FloatSlider(min=0, max=5000, step=10),
              T0=FloatSlider(min=0, max=1, step=0.05),
              u0=FloatSlider(min=0, max=1, step=0.05),
              v0=FloatSlider(min=0, max=1, step=0.01),
              D=FloatSlider(min=-1, max=1, step=0.05),
              m=IntSlider(min=50, max=5000, step=100),
             )
w

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=300
    b=30
    x=0.2
    s = 5
    m1 = m / s
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m     
    for k in range(1, m):
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)

        
        
    
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    plt.plot(tv,'.' )
    return tv[k]
a = lr_schedule(450)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=50
    b=10
    x=0.2
    s = 5
    s1 = s
    m1 = m/s
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m  
    
    for m
        for k in range(1, m):
            T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])
#     for k in range(0, m):
#         u[k+1] = (1/(1+np.exp(-v[k]/lam)))
#         v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
#         tv[k] = math.sqrt((T[k]-v[k])**2)
            if ( (k % (m/s)) == 0 ) :
                 m1 -=1
                 print(m1)
            T[k] = (T[k] / s)*m1 
        
          
                
                 

        
        
    
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
#     plt.plot(tv,'.' )
    return tv[k]
a = lr_schedule(450)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=300
    b=10
    x=0.2
    s = 5
    s1 = s-1
    m1 = m / s 
    Tmax = 0.015
    T0=Tmax 
    Tb = T0 / s
    u0=0.75
    v0=0.001
    tv0=0
    k1 = 1
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m  
    
    
    for k in range(1, m):
        
#         T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* T[k1-1])
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* Tb)
        Tb = T[k]

        if ( (k % (m/s)) == 0 ) :
            Tb = T0 / s
            s1 -=1
            print(s1)
            k1 = 1
            T[k] = (T[k] )+(Tmax/s)
#             print(k1)
#         print("Tk = " , T[k])
        T[k] = (T[k] )+(Tmax/s) *s1
#         T0 = T[k]
#         print("Tkm = " ,(Tmax/s) *s1)
#         print("Tka = " , T[k])
        k1 +=1

#             T[k] = (T[k] / s)*m1 
#     for k in range(0, m):
#         u[k+1] = (1/(1+np.exp(-v[k]/lam)))
#         v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
#         tv[k] = math.sqrt((T[k]-v[k])**2)        
                                         
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
#     plt.plot(tv,'.' )
    return tv[k]
a = lr_schedule(300)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=300
    b=30
    x=0.2
    s = 3
    s1 = s-1
    m1 = m / s 
    Tmax = 0.02
    T0=Tmax 
    Tb = T0 / s
    u0=0.75
    v0=0.001
    tv0=0
    k1 = 1
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m  
    
    
    for k in range(1, m):
        
#         T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* T[k1-1])
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* Tb)
        Tb = T[k]

        if ( (k % (m/s)) == 0 ) :
            Tb = T0 / s
            s1 -=1
            print(s1)
            k1 = 1
            T[k] = (T[k] )+(Tmax/s)
#             print(k1)
#         print("Tk = " , T[k])
        T[k] = (T[k] )+(Tmax/s) *s1
#         T0 = T[k]
#         print("Tkm = " ,(Tmax/s) *s1)
#         print("Tka = " , T[k])
        k1 +=1

#             T[k] = (T[k] / s)*m1 
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)        
                                         
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    plt.plot(tv,'.' )
    return tv[k]
a = lr_schedule(300)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def lr_schedule(epoch):

    delta=0.30
    lam=7500
    D=0
    I0=0.95
    m=303
    b=50
    x=0.2
    s = 3
    s1 = s-1
    m1 = m / s 
    Tmax = 0.02
    T0=Tmax 
    Tb = T0 / s
    Tb1 = Tmax
    u0=0.75
    ub = u0 
    v0=0.001
    vb = v0 
    tv0=0
    k1 = 1
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[Tmax] + [0] * m  
    
    
    for k in range(1, m):
        
#         T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* T[k1-1])
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* Tb)
        
        u[k] = (1/(1+np.exp(-vb/lam)))
        v[k] = (delta*math.sin(math.pi*vb)+D-Tb*(ub-I0))
        
        Tb = T[k]
        ub = u[k]
        vb = v[k]
#         tvb = Tb

        if ( (k % (m/s)) == 0 ) :
            Tb = T0 / s
            ub = u0
#             vb = v0
#             Tb1 = T0
            s1 -=1
            print(s1)
            k1 = 1
            T[k] = (T[k] )+(Tmax/s)
#             v[k] = (v[k] )+(Tmax/s)
#             print(k1)
#         print("Tk = " , T[k])
#         else :
        T[k] = (T[k] )+(Tmax/s) *s1
#             v[k] = (v[k] )+(Tmax/s) *s1
#         T0 = T[k]
#         Tb1 = T[k]
#         print("Tkm = " ,(Tmax/s) *s1)
#         print("Tka = " , T[k])
        k1 +=1
        tv[k] = math.sqrt((T[k]-v[k])**2) 
#         print("tv[",k,"] = ",tv[k])

#             T[k] = (T[k] / s)*m1 
#     for k in range(0, m):
#         u[k+1] = (1/(1+np.exp(-v[k]/lam)))
#         v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
#         tv[k] = math.sqrt((T[k]-v[k])**2)        
                                         
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
#     plt.plot(v,'.' )

    plt.plot(tv,'.' )
    
    return tv[k]
a = lr_schedule(318)

# %%
##### from keras import backend as K
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
def AL_lr_schedule(epoch):
    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=350
    b=85
#     b = 20
    x=0.2
    
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m     
    for k in range(1, m):
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)
#     print('Learning rate: ', tv[epoch])
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
#     plt.plot(tv,'.' )
    plt.savefig("lrAL329.png")

    return T[epoch]

a = AL_lr_schedule(40)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def CHAL_lr_P_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=300
    b=30
    x=0.2
    s = 3
    s1 = s-1
    m1 = m / s 
    Tmax = 0.02
    T0=Tmax 
    Tb = T0 / s
    u0=0.75
    v0=0.001
    tv0=0
    k1 = 1
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m  
    
    
    for k in range(1, m):
        
#         T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* T[k1-1])
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* Tb)
        Tb = T[k]

        if ( (k % (m/s)) == 0 ) :
            Tb = T0 / s
            s1 -=1
#             print(s1)
            k1 = 1
            T[k] = (T[k] )+(Tmax/s)
#             print(k1)
#         print("Tk = " , T[k])
        T[k] = (T[k] )+(Tmax/s) *s1
#         T0 = T[k]
#         print("Tkm = " ,(Tmax/s) *s1)
#         print("Tka = " , T[k])
        k1 +=1

#             T[k] = (T[k] / s)*m1 
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)        
                                         
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
    plt.plot(tv,'.' )
    return tv[k]
a = CHAL_lr_P_schedule(300)

# %%
##### from keras import backend as K
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline
def CHAL_lr_schedule(epoch):
    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=365
    b=121
#     b = 20
    x=0.2
    
    T0=0.015
    u0=0.75
    v0=0.001
    tv0=0
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m     
    for k in range(1, m):
        T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k))* T[k-1])
    for k in range(0, m):
        u[k+1] = (1/(1+np.exp(-v[k]/lam)))
        v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
        tv[k] = math.sqrt((T[k]-v[k])**2)
#     print('Learning rate: ', tv[epoch])
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
#     plt.plot(tv,'.' )
    plt.plot(T,'.' )
    return tv[epoch]

a = CHAL_lr_schedule(40)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def CHAL_lr_P_schedule(epoch):

    delta=0.30
    lam=2500
    D=0
    I0=0.95
    m=300
    b=30
    x=0.2
    s = 3
    s1 = s-1
    m1 = m / s 
    Tmax = 0.01
    T0=Tmax 
    Tb = T0 
    u0=0.75
    v0=0.001
    tv0=0
    k1 = 1
    assert lam != 0
    lam = 1 / lam
    T=[T0] + [0] * m #2.73
    u = [u0] + [0] * m 
    v=[v0] + [0] * m 
    tv=[tv0] + [0] * m  
    
    
    for k in range(1, m):     
#         T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* T[k1-1])
        if ( (k % (m/s)) == 0 ) :
            Tb = T0 / 10
#             T[k] = 0.01
        T[k] = Tb
#             s1 -=1
#             print(s1)
#             k1 = 1
#             T[k] = (T[k] )+(Tmax/s)
#             print(k1)
#         print("Tk = " , T[k])
#         T[k] = (T[k] )+(Tmax/s) *s1
#         T0 = T[k]
#         print("Tkm = " ,(Tmax/s) *s1)
#         print("Tka = " , T[k])
#         k1 +=1

#             T[k] = (T[k] / s)*m1 
#     for k in range(0, m):
#         u[k+1] = (1/(1+np.exp(-v[k]/lam)))
#         v[k+1] = (delta*math.sin(math.pi*v[k])+D-T[k]*(u[k]-I0))
#         tv[k] = math.sqrt((T[k]-v[k])**2)        
                                         
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    plt.plot(T,'.' )
#     plt.plot(tv,'.' )
    return tv[k]
a = CHAL_lr_P_schedule(300)

# %%
from ipywidgets import interactive, fixed, FloatSlider, IntSlider
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# %matplotlib inline

def CHAL_lr_P_schedule(epoch):

    m=300
    T0=0.1
    lr =0.1
    s = 1
    T=[T0] + [0] * m #2.73

    
    
    for k in range(1, m):     
#         T[k] = ((1 / (b + 1)) * (b + (math.tanh(x) ** k1))* T[k1-1])
        if ( k <= 50 ) :
           T[k] = 0.1
        elif ( k <= 100 ) :
            T[k] = 0.075
        elif ( k <= 150 ) :
            T[k] = 0.05
        elif ( k <= 200 ) :
            T[k] = 0.025
        elif ( k <= 250 ) :
            T[k] = 0.01
        else :
            T[k] = 0.0075
        
        

  
                                         
    f = plt.figure(figsize=(13,5))
    sns.set_style("darkgrid")
    
    plt.plot(T,'.' )
    plt.savefig("lr.png")
#     plt.plot(tv,'.' )
    return T[k]
a = CHAL_lr_P_schedule(300)
